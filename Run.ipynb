# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          99G   75G   19G  80% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs            30G     0   30G   0% /sys/fs/cgroup
# shm             1.0G  412K  1.0G   1% /dev/shm
# /dev/xvdb1       99G   75G   19G  80% /etc/hosts
# tmpfs            30G   12K   30G   1% /proc/driver/nvidia
# /dev/xvda1       48G  9.1G   36G  21% /usr/bin/nvidia-smi
# udev             30G     0   30G   0% /dev/nvidia1
# tmpfs            30G     0   30G   0% /proc/acpi
# tmpfs            30G     0   30G   0% /proc/scsi
# tmpfs            30G     0   30G   0% /sys/firmware

# %%
# !nvidia-smi
# Out:
# Thu Apr 22 06:16:06 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P40           On   | 00000000:00:06.0 Off |                  Off |
# | N/A   67C    P0    67W / 250W |      0MiB / 24451MiB |     47%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
cd code
# Out:
# /opt/ml/code

# %%
# !pip install -r ./requirements.txt
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 2.0 MB/s eta 0:00:01     |█████████████████▉              | 1.1 MB 2.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 121 kB 8.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1 MB 8.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 256 kB 12.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.3 MB 10.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.2 MB 13.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 243 kB 13.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 131 kB 13.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 7.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 163 kB 13.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.7 MB 13.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 74 kB 5.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 68 kB 9.1 MB/s  eta 0:00:01
# ...

# %%
cd
# Out:
# /opt/ml

# %%
# !tar -zcvf final.tar.gz /opt/ml/code
# Out:
# tar: Removing leading `/' from member names
# /opt/ml/code/
# /opt/ml/code/Run.ipynb
# /opt/ml/code/train_test.py
# /opt/ml/code/inference.py
# /opt/ml/code/load_entity.py
# /opt/ml/code/test.csv
# /opt/ml/code/inference-entity.py
# /opt/ml/code/prediction/
# /opt/ml/code/prediction/k-1-robert.csv
# /opt/ml/code/prediction/submission.csv
# /opt/ml/code/prediction/kobert-5.csv
# /opt/ml/code/prediction/k-3-robert.csv
# /opt/ml/code/prediction/kobert-1.csv
# /opt/ml/code/prediction/.ipynb_checkpoints/
# /opt/ml/code/prediction/.ipynb_checkpoints/submission-checkpoint.csv
# /opt/ml/code/prediction/.ipynb_checkpoints/k-3-robert-checkpoint.csv
# /opt/ml/code/prediction/.ipynb_checkpoints/k-1-robert-checkpoint.csv
# /opt/ml/code/prediction/.ipynb_checkpoints/kobert-1-checkpoint.csv
# /opt/ml/code/logits/
# /opt/ml/code/logits/logits.npy
# /opt/ml/code/results/
# /opt/ml/code/results/.ipynb_checkpoints/
# /opt/ml/code/datatest.ipynb
# /opt/ml/code/requirements.txt
# ...

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# !python train.py
# Out:
# wandb: Currently logged in as: bongjinkim (use `wandb login --relogin` to force relogin)
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.10.27
# wandb: Syncing run effortless-resonance-2368
# wandb: ⭐️ View project at https://wandb.ai/bongjinkim/bert-test
# wandb: 🚀 View run at https://wandb.ai/bongjinkim/bert-test/runs/29i9ld90
# wandb: Run data is saved locally in /opt/ml/code/wandb/run-20210422_124837-29i9ld90
# wandb: Run `wandb offline` to turn off syncing.
#
# ^C
# Traceback (most recent call last):
#   File "train.py", line 182, in <module>
#     main()
#   File "train.py", line 179, in main
#     train()
#   File "train.py", line 138, in train
#     model = load_model(find_path(config.model_name), config=bert_config)
# ...

# %%
# !python inference-entity.py --model_name XLMRobertaForSequenceClassification --tokenizer_name XLMRobertaTokenizer --model_path ./results/checkpoint-1600 --k_num 1
# Out:
# 50it [00:14,  3.54it/s]

# %%
import json
import requests
import os
def submit(user_key='', file_path = ''):
    if not user_key:
        raise Exception("No UserKey" )
    #competition/{url에 나와있는 숫자}/
    url = 'http://ec2-13-124-161-225.ap-northeast-2.compute.amazonaws.com:8000/api/v1/competition/4/presigned_url/?description=&hyperparameters={%22training%22:{},%22inference%22:{}}'
    headers = {
        'Authorization': user_key
    }
    res = requests.get(url, headers=headers)
    data = json.loads(res.text)
    submit_url = data['url']
    body = {
        #app/Competitions/{url에 나와있는 숫자, 정확히는 F12-Network-"data_url"}
        'key':'app/Competitions/000004/Users/{}/Submissions/{}/output.csv'.format(str(data['submission']['user']).zfill(8),str(data['submission']['local_id']).zfill(4)),
        'x-amz-algorithm':data['fields']['x-amz-algorithm'],
        'x-amz-credential':data['fields']['x-amz-credential'],
        'x-amz-date':data['fields']['x-amz-date'],
        'policy':data['fields']['policy'],
        'x-amz-signature':data['fields']['x-amz-signature']
    }
    requests.post(url=submit_url, data=body, files={'file': open(file_path, 'rb')})
#os.path.join("./prediction/", 'submission.csv')
submit("Bearer 0fdbed1f585d373faa764fd5a27e1752da997bda", os.path.join("/opt/ml/code/prediction/", 'submission.csv'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-91a3befa371b> in <module>
#      24     requests.post(url=submit_url, data=body, files={'file': open(file_path, 'rb')})
#      25 #os.path.join("./prediction/", 'submission.csv')
# ---> 26 submit("Bearer 0fdbed1f585d373faa764fd5a27e1752da997bda", os.path.join("/opt/ml/code/prediction/", 'submission.csv'))
#
# <ipython-input-113-91a3befa371b> in submit(user_key, file_path)
#      12     res = requests.get(url, headers=headers)
#      13     data = json.loads(res.text)
# ---> 14     submit_url = data['url']
#      15     body = {
#      16         #app/Competitions/{url에 나와있는 숫자, 정확히는 F12-Network-"data_url"}
#
# KeyError: 'url'
